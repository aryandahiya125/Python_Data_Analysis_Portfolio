# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:/Users/DELL/Downloads/airbnb (1).csv")

# %%
df.head()
# Out:
#          id                                               name rating reviews  \
# 0  49849504                                     Perla bungalov   4.71      64
# 1  50891766  Authentic Beach Architect Sheltered Villa with...    New     NaN
# 2  50699164                                  cottages sataplia   4.85      68
# 3  49871422                        Sapanca Breathable Bungalow    5.0      13
# 4  51245886                                      Bungalov Ev 2    New     NaN
#
#                                host_name      host_id  \
# 0    Entire bungalow hosted by Mehmetcan  357334205.0
# 1           Entire villa hosted by Fatih  386223873.0
# 2          Entire cabin hosted by Giorgi  409690853.0
# 3        Entire bungalow hosted by Melih  401873242.0
# 4  Entire bungalow hosted by Arp Sapanca  414884116.0
#
#                     address                                features  \
# 0  Kartepe, Kocaeli, Turkey    2 guests,2 bedrooms,1 bed,1 bathroom
# ...

# %%
df.describe()
# Out:
#                  id       host_id
# count  1.445600e+04  1.401700e+04
# mean   7.138227e+16  1.619384e+08
# std    1.962072e+17  1.403407e+08
# min    1.313100e+04  2.303900e+04
# 25%    2.047078e+07  3.603925e+07
# 50%    3.524320e+07  1.243490e+08
# 75%    4.951689e+07  2.607109e+08
# max    7.017905e+17  4.758973e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14456 entries, 0 to 14455
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            14456 non-null  int64
#  1   name          14455 non-null  object
#  2   rating        14456 non-null  object
#  3   reviews       11712 non-null  object
#  4   host_name     14455 non-null  object
#  5   host_id       14017 non-null  float64
#  6   address       14429 non-null  object
#  7   features      14429 non-null  object
#  8   amenities     13467 non-null  object
#  9   safety_rules  14247 non-null  object
#  10  hourse_rules  14247 non-null  object
#  11  img_links     14429 non-null  object
#  12  price         14456 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# id                 0
# name               1
# rating             0
# reviews         2744
# host_name          1
# host_id          439
# address           27
# features          27
# amenities        989
# safety_rules     209
# hourse_rules     209
# img_links         27
# price              0
# dtype: int64

# %%
df[df['reviews'].isnull()]
# Out:
#                        id                                               name  \
# 1                50891766  Authentic Beach Architect Sheltered Villa with...
# 4                51245886                                      Bungalov Ev 2
# 5                48650769                      CasaMia White Suite Treehouse
# 6                50765985                                     Ladin Bungalow
# 7                40947216                                     Lavender House
# ...                   ...                                                ...
# 14436  621278037552014887        Kintamani Glamping Black Lava Camp Potato 3
# 14439  624406715458043020         Kintamani Glamping Black Lava Camp Onion 3
# 14443  621201623913222432        Kintamani Glamping Black Lava camp Potato 2
# 14445            44045739                                       Tambu a mare
# 14449  640474109823176234                            Holiday home, Plemmirio
#
# ...

# %%
df.dropna(subset=['reviews'],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# reviews           0
# host_name         0
# host_id         207
# address           0
# features          0
# amenities       716
# safety_rules     95
# hourse_rules     95
# img_links         0
# price             0
# dtype: int64

# %%
df[df['host_id'].isnull()]
# Out:
#                        id                         name rating reviews  \
# 725    588250406117563784  Maison Cardinal Furstemberg    5.0       6
# 801              35839817                       Icaria    5.0       3
# 861              31378793               Villa Grenache    New       1
# 2337             20473398                Villa Sawarin    New       1
# 2339             20470768         Samujana Twenty-Four    New       1
# ...                   ...                          ...    ...     ...
# 12495            20473522                  Baan Wanora    5.0       4
# 13873            20475667             Baan Kata Keeree   4.57       7
# 13927            24231704                   Naam Sawan    New       1
# 13945            20472623                  Villa Padma    5.0       3
# 13983            20472323     Amarelo 2 at Sava Villas   4.67       6
#
#                                                host_name  host_id  \
# ...

# %%
df.dropna(subset=['host_id'],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# reviews           0
# host_name         0
# host_id           0
# address           0
# features          0
# amenities       509
# safety_rules     95
# hourse_rules     95
# img_links         0
# price             0
# dtype: int64

# %%
df[df['amenities'].isnull()]
# Out:
#              id                                               name rating  \
# 132    33343364                          Glamping Forest Edge #No3    New
# 136    33343138                          Glamping Forest Edge #No2    New
# 241    33325892          Mao Mao surf (Jungle hut 3: Drunk parrot)   4.93
# 487    24035045                                         Media Luna   4.96
# 513    34932382  Double or Twin Room - Magical West Fjords Latr...    4.6
# ...         ...                                                ...    ...
# 14079  38938788                   Beach Bungalow in the Rainforest    4.9
# 14108  32820525      Shrikanchan Bungalow by Kolthare Beach Dapoli    New
# 14119  26155377  IVORY STD Double (Clean room & Care your holiday)   4.74
# 14142  33429446                    lovely rest,free island hopping   4.71
# 14424  22285856                                   LA CASA HIBISCUS   4.88
#
#       reviews                                     host_name      host_id  \
# ...

# %%
df.fillna({'amenities':'no amenities'},inplace=True)

# %%
df[df['amenities']=='no amenities']
# Out:
#              id                                               name rating  \
# 132    33343364                          Glamping Forest Edge #No3    New
# 136    33343138                          Glamping Forest Edge #No2    New
# 241    33325892          Mao Mao surf (Jungle hut 3: Drunk parrot)   4.93
# 487    24035045                                         Media Luna   4.96
# 513    34932382  Double or Twin Room - Magical West Fjords Latr...    4.6
# ...         ...                                                ...    ...
# 14079  38938788                   Beach Bungalow in the Rainforest    4.9
# 14108  32820525      Shrikanchan Bungalow by Kolthare Beach Dapoli    New
# 14119  26155377  IVORY STD Double (Clean room & Care your holiday)   4.74
# 14142  33429446                    lovely rest,free island hopping   4.71
# 14424  22285856                                   LA CASA HIBISCUS   4.88
#
#       reviews                                     host_name      host_id  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# name             0
# rating           0
# reviews          0
# host_name        0
# host_id          0
# address          0
# features         0
# amenities        0
# safety_rules    95
# hourse_rules    95
# img_links        0
# price            0
# dtype: int64

# %%
df['safety_rules']
# Out:
# 0        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 2        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3        󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 9        󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 10       󹀁,Airbnb's COVID-19 safety practices apply,Car...
#                                ...
# 14451    󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454    󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
# Name: safety_rules, Length: 11505, dtype: object

# %%
df.fillna({'safety_rules':'no rules'},inplace=True)

# %%
df.isnull().sum()
# Out:
# id               0
# name             0
# rating           0
# reviews          0
# host_name        0
# host_id          0
# address          0
# features         0
# amenities        0
# safety_rules     0
# hourse_rules    95
# img_links        0
# price            0
# dtype: int64

# %%
df['hourse_rules']
# Out:
# 0        Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 2        Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3        Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 9               Check-in: After 3:00 pm,No smoking,No pets
# 10       Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...
#                                ...
# 14451    Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452    Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                              Check-in: After 3:00 pm
# 14454    Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455    Check-in: After 4:00 pm,Check out: 11:00 am,Se...
# Name: hourse_rules, Length: 11505, dtype: object

# %%
df['hourse_rules'].fillna('Check-in: Flexible,Check out: 12:00 pm',inplace=True)

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# rating          0
# reviews         0
# host_name       0
# host_id         0
# address         0
# features        0
# amenities       0
# safety_rules    0
# hourse_rules    0
# img_links       0
# price           0
# dtype: int64

# %%
df[df['rating']=='New']
# Out:
#                        id                                               name  \
# 27     629647204973611229  Bungalows with private pools in touch with nature
# 37     626028165124157941  Sapanca Nature Bungalow Suite with Pool and Ja...
# 42     610745734737149895                                  LAKERS BUNGALOV 3
# 47     592431497070075673       Bungalow with Heated Private Pool in Sapanca
# 49               50664527                             SAPANCA ELİTE BUNGALOW
# ...                   ...                                                ...
# 14420            42004055                      Bubble Hotel Bali Nyang Nyang
# 14425  614428833932294155                          Arctic Dome med badestamp
# 14431            49520144                  넷플릭스/유튜브/바베큐이벤트/성산일출봉/우도/감성펜션-달별2
# 14440            53925646  Dome2 Rooms Dome2 in a home where you can esca...
# 14441            41257160    Romantic stay at Tent galaxy villa with jacuzzi
#
# ...

# %%
df['rating']=df['rating'].replace('New',0.0)

# %%
df[df['rating']==0.0]
# Out:
#                        id                                               name  \
# 27     629647204973611229  Bungalows with private pools in touch with nature
# 37     626028165124157941  Sapanca Nature Bungalow Suite with Pool and Ja...
# 42     610745734737149895                                  LAKERS BUNGALOV 3
# 47     592431497070075673       Bungalow with Heated Private Pool in Sapanca
# 49               50664527                             SAPANCA ELİTE BUNGALOW
# ...                   ...                                                ...
# 14420            42004055                      Bubble Hotel Bali Nyang Nyang
# 14425  614428833932294155                          Arctic Dome med badestamp
# 14431            49520144                  넷플릭스/유튜브/바베큐이벤트/성산일출봉/우도/감성펜션-달별2
# 14440            53925646  Dome2 Rooms Dome2 in a home where you can esca...
# 14441            41257160    Romantic stay at Tent galaxy villa with jacuzzi
#
# ...

# %%
df['rating']=df['rating'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11505 entries, 0 to 14455
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            11505 non-null  int64
#  1   name          11505 non-null  object
#  2   rating        11505 non-null  float64
#  3   reviews       11505 non-null  object
#  4   host_name     11505 non-null  object
#  5   host_id       11505 non-null  float64
#  6   address       11505 non-null  object
#  7   features      11505 non-null  object
#  8   amenities     11505 non-null  object
#  9   safety_rules  11505 non-null  object
#  10  hourse_rules  11505 non-null  object
#  11  img_links     11505 non-null  object
#  12  price         11505 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# rating          0
# reviews         0
# host_name       0
# host_id         0
# address         0
# features        0
# amenities       0
# safety_rules    0
# hourse_rules    0
# img_links       0
# price           0
# dtype: int64

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews                            host_name      host_id  \
# 0       64  Entire bungalow hosted by Mehmetcan  357334205.0
# 2       68        Entire cabin hosted by Giorgi  409690853.0
# 3       13      Entire bungalow hosted by Melih  401873242.0
# 9        3        Entire home hosted by Sukanya  173126583.0
# 10      77               Farm stay hosted by 동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# ...

# %%
df['host_name']=df['host_name'].str.split('by').str[1]

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews   host_name      host_id  \
# 0       64   Mehmetcan  357334205.0
# 2       68      Giorgi  409690853.0
# 3       13       Melih  401873242.0
# 9        3     Sukanya  173126583.0
# 10      77          동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
df['host_name']=df['host_name'].str.strip()

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
df['host_id']=df['host_id'].astype(object)

# %%
df['address']
# Out:
# 0                                 Kartepe, Kocaeli, Turkey
# 2                                         Imereti, Georgia
# 3                                 Sapanca, Sakarya, Turkey
# 9        Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# 10       Sanoe-myeon, Boeun-gun, North Chungcheong Prov...
#                                ...
# 14451    Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 14452                                   Gianyar, Indonesia
# 14453                                       Kabale, Uganda
# 14454          Gunung Sari, Nusa Tenggara Barat, Indonesia
# 14455                                Uruma, Okinawa, Japan
# Name: address, Length: 11505, dtype: object

# %%
df['country']=df['address'].str.split(',').str[-1].str.strip()

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
df[['host_id','host_name']].value_counts()
# Out:
# host_id      host_name
# 157378426.0  Shanu                  38
# 233211645.0  HotelSnow              13
# 338168125.0  The Arctic Hideaway    13
# 105199196.0  Paolo                  12
# 7455203.0    Alessandro&Anna        11
#                                     ..
# 464516539.0  Živilė                  1
# 465060011.0  Αρτεμης-Νικολας         1
# 465165092.0  Tamar                   1
# 465187114.0  Sakshi                  1
# 465333640.0  Elton                   1
# Name: count, Length: 9136, dtype: int64

# %%
df['hourse_rules']
# Out:
# 0        Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 2        Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3        Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 9               Check-in: After 3:00 pm,No smoking,No pets
# 10       Check-in: 3:00 pm - 9:00 pm,Check out: 11:00 a...
#                                ...
# 14451    Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452    Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                              Check-in: After 3:00 pm
# 14454    Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455    Check-in: After 4:00 pm,Check out: 11:00 am,Se...
# Name: hourse_rules, Length: 11505, dtype: object

# %%
df['check_in']=df['hourse_rules'].str.split(',').str[0].str.split('in:').str[1].str.strip()

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
df['check_out']=df['hourse_rules'].str.split(',').str[1].str.split('out:').str[1].str.strip().fillna('12:00 pm')

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
del df['img_links']

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
df['features']
# Out:
# 0                2 guests,2 bedrooms,1 bed,1 bathroom
# 2                4 guests,1 bedroom,3 beds,1 bathroom
# 3                4 guests,1 bedroom,2 beds,1 bathroom
# 9             10 guests,4 bedrooms,6 beds,3 bathrooms
# 10                4 guests,1 bedroom,1 bed,1 bathroom
#                              ...
# 14451                            4 guests,8 bathrooms
# 14452       2 guests,1 bedroom,1 bed,Toilet with sink
# 14453    2 guests,1 bedroom,2 beds,1 private bathroom
# 14454        8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 14455            5 guests,1 bedroom,2 beds,1 bathroom
# Name: features, Length: 11505, dtype: object

# %%
df['no_of_guest']=df['features'].str.split(',').str[0].str.split().str[0].str.strip().astype(int)

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
df['no_of_bedroom']=df['features'].str.split(',').str[1].str.split().str[0].str.strip()

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
df['features']=df['features'].str.replace('bedrooms','bedroom').str.replace('beds','bed').str.replace('bathrooms','bathroom')

# %%
df['features']
# Out:
# 0                2 guests,2 bedroom,1 bed,1 bathroom
# 2                4 guests,1 bedroom,3 bed,1 bathroom
# 3                4 guests,1 bedroom,2 bed,1 bathroom
# 9               10 guests,4 bedroom,6 bed,3 bathroom
# 10               4 guests,1 bedroom,1 bed,1 bathroom
#                             ...
# 14451                            4 guests,8 bathroom
# 14452      2 guests,1 bedroom,1 bed,Toilet with sink
# 14453    2 guests,1 bedroom,2 bed,1 private bathroom
# 14454          8 guests,2 bedroom,4 bed,2.5 bathroom
# 14455            5 guests,1 bedroom,2 bed,1 bathroom
# Name: features, Length: 11505, dtype: object

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
df['price']=df['price'].str.split().str[0].str.split('₹').str[1].str.replace(',','').str.strip().astype(int)

# %%
df.head()
# Out:
#           id                                               name  rating  \
# 0   49849504                                     Perla bungalov    4.71
# 2   50699164                                  cottages sataplia    4.85
# 3   49871422                        Sapanca Breathable Bungalow    5.00
# 9   42075682                    The Cottage, Private Pool Villa    4.67
# 10  50425621  A private pension hut on the hillside of Sokli...    4.97
#
#    reviews  host_name      host_id  \
# 0       64  Mehmetcan  357334205.0
# 2       68     Giorgi  409690853.0
# 3       13      Melih  401873242.0
# 9        3    Sukanya  173126583.0
# 10      77         동현   81358542.0
#
#                                               address  \
# 0                            Kartepe, Kocaeli, Turkey
# 2                                    Imereti, Georgia
# 3                            Sapanca, Sakarya, Turkey
# 9   Tambon Bang Kachai, Chang Wat Chanthaburi, Tha...
# ...

# %%
#Which countries have the most airbnb listings?
df.groupby('country')['id'].count().sort_values(ascending=False)
# Out:
# country
# India            2414
# Italy             997
# Greece            916
# Thailand          576
# France            459
#                  ...
# St Martin           1
# Tunisia             1
# Uruguay             1
# Vanuatu             1
# Åland Islands       1
# Name: id, Length: 114, dtype: int64

# %%
df.count()
# Out:
# id               11505
# name             11505
# rating           11505
# reviews          11505
# host_name        11505
# host_id          11505
# address          11505
# features         11505
# amenities        11505
# safety_rules     11505
# hourse_rules     11505
# price            11505
# country          11505
# check_in         11021
# check_out        11505
# no_of_guest      11505
# no_of_bedroom    11505
# dtype: int64

# %%
#How does the number of reviews related to the rating of a listing?
df.groupby('reviews')['rating'].count().sort_values(ascending=False)
# Out:
# reviews
# 1        1228
# 2         756
# 3         502
# 4         349
# 5         333
#          ...
# 703         1
# 232         1
# 716         1
# 807         1
# 1,003       1
# Name: rating, Length: 423, dtype: int64

# %%
df.to_csv('airbnbnew',index=False)
